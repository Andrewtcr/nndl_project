# %%
# !pip install diffusers

# %%
# !pip install datasets transformers accelerate

# %%
# !python3 data.py
# Out:
# 2022-12-19 04:49:53.603167: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Fetching 12 files: 100% 12/12 [00:00<00:00, 23819.99it/s]
# Afghan hound, Afghan
# 100% 25/25 [00:02<00:00, 10.69it/s]
# 100% 25/25 [00:01<00:00, 20.73it/s]
# 100% 25/25 [00:01<00:00, 20.84it/s]
# 100% 25/25 [00:01<00:00, 21.13it/s]
# 100% 25/25 [00:01<00:00, 21.10it/s]
# 100% 25/25 [00:01<00:00, 20.97it/s]
# 100% 25/25 [00:01<00:00, 20.72it/s]
# 100% 25/25 [00:01<00:00, 20.74it/s]
# 100% 25/25 [00:01<00:00, 21.03it/s]
# 100% 25/25 [00:01<00:00, 20.72it/s]
# 100% 25/25 [00:01<00:00, 21.00it/s]
# 100% 25/25 [00:01<00:00, 20.58it/s]
# 100% 25/25 [00:01<00:00, 21.13it/s]
# 100% 25/25 [00:01<00:00, 20.82it/s]
# 100% 25/25 [00:01<00:00, 21.11it/s]
# 100% 25/25 [00:01<00:00, 21.08it/s]
# ...

# %%
# !zip -r x_generated.zip x_generated
# Out:
#   adding: x_generated/ (stored 0%)
#   adding: x_generated/512.jpg (deflated 28%)
#   adding: x_generated/755.jpg (deflated 28%)
#   adding: x_generated/1585.jpg (deflated 28%)
#   adding: x_generated/3643.jpg (deflated 29%)
#   adding: x_generated/2343.jpg (deflated 29%)
#   adding: x_generated/3070.jpg (deflated 28%)
#   adding: x_generated/1667.jpg (deflated 28%)
#   adding: x_generated/2660.jpg (deflated 29%)
#   adding: x_generated/2770.jpg (deflated 29%)
#   adding: x_generated/1563.jpg (deflated 28%)
#   adding: x_generated/2339.jpg (deflated 29%)
#   adding: x_generated/4410.jpg (deflated 29%)
#   adding: x_generated/3603.jpg (deflated 29%)
#   adding: x_generated/1533.jpg (deflated 29%)
#   adding: x_generated/3103.jpg (deflated 29%)
#   adding: x_generated/1432.jpg (deflated 29%)
#   adding: x_generated/3399.jpg (deflated 29%)
#   adding: x_generated/3461.jpg (deflated 29%)
#   adding: x_generated/3061.jpg (deflated 28%)
#   adding: x_generated/1100.jpg (deflated 28%)
# ...
